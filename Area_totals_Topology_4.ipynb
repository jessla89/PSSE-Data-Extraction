# %% [markdown]
# ### Year 3 Topology 4 System Totals

# %%
import pandas as pd

# %%
def area_select(area_name):
    '''
    function to select area data by area name
    '''
    list_area = []
    list_gens = [0,50,100]
    list_lsc = ['LLS','RLS','HLS']
    list_gen_hydro = [400,500,600] #dry, average, wet hydological scenarios
    for gen in list_gens:
        for gen_hy in list_gen_hydro:
            for lsc in list_lsc:
                file_csv_in = 'savnw_sol_' + str(gen) +'_hy_' +str(gen_hy) +'_' + str(lsc)+'_tot.csv'
                data_tot = pd.read_csv(file_csv_in)
                data_tot['Scenario'] = 'Solar = ' + str(gen) + ' MW, ' + 'Hydro = ' + str(gen_hy) + ' MW, '+ lsc.upper()
                data_area = data_tot[data_tot['Area'].str.strip() == area_name]
                list_area.append(data_area)
    df_area = pd.concat(list_area)
    df = df_area[['Scenario','Area', 'Number', 'From Generation', 'To Load', 'To(+)/From(-) Ties',
           'To Losses']].reset_index(drop=True)
    return df

# %% [markdown]
# ##### Area Selection

# %% [markdown]
# Filtering out totals for each scenarios by area

# %%
area_select('FLAPCO')
# Out:
#                                Scenario          Area  Number  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS  FLAPCO             1
# 1     Solar = 0 MW, Hydro = 400 MW, RLS  FLAPCO             1
# 2     Solar = 0 MW, Hydro = 400 MW, HLS  FLAPCO             1
# 3     Solar = 0 MW, Hydro = 500 MW, LLS  FLAPCO             1
# 4     Solar = 0 MW, Hydro = 500 MW, RLS  FLAPCO             1
# 5     Solar = 0 MW, Hydro = 500 MW, HLS  FLAPCO             1
# 6     Solar = 0 MW, Hydro = 600 MW, LLS  FLAPCO             1
# 7     Solar = 0 MW, Hydro = 600 MW, RLS  FLAPCO             1
# 8     Solar = 0 MW, Hydro = 600 MW, HLS  FLAPCO             1
# 9    Solar = 50 MW, Hydro = 400 MW, LLS  FLAPCO             1
# 10   Solar = 50 MW, Hydro = 400 MW, RLS  FLAPCO             1
# 11   Solar = 50 MW, Hydro = 400 MW, HLS  FLAPCO             1
# 12   Solar = 50 MW, Hydro = 500 MW, LLS  FLAPCO             1
# 13   Solar = 50 MW, Hydro = 500 MW, RLS  FLAPCO             1
# 14   Solar = 50 MW, Hydro = 500 MW, HLS  FLAPCO             1
# 15   Solar = 50 MW, Hydro = 600 MW, LLS  FLAPCO             1
# 16   Solar = 50 MW, Hydro = 600 MW, RLS  FLAPCO             1
# 17   Solar = 50 MW, Hydro = 600 MW, HLS  FLAPCO             1
# 18  Solar = 100 MW, Hydro = 400 MW, LLS  FLAPCO             1
# 19  Solar = 100 MW, Hydro = 400 MW, RLS  FLAPCO             1
# 20  Solar = 100 MW, Hydro = 400 MW, HLS  FLAPCO             1
# 21  Solar = 100 MW, Hydro = 500 MW, LLS  FLAPCO             1
# 22  Solar = 100 MW, Hydro = 500 MW, RLS  FLAPCO             1
# 23  Solar = 100 MW, Hydro = 500 MW, HLS  FLAPCO             1
# 24  Solar = 100 MW, Hydro = 600 MW, LLS  FLAPCO             1
# 25  Solar = 100 MW, Hydro = 600 MW, RLS  FLAPCO             1
# 26  Solar = 100 MW, Hydro = 600 MW, HLS  FLAPCO             1
#
#     From Generation  To Load  To(+)/From(-) Ties  To Losses
# 0              1381     1113                 249         18
# 1              1444     1174                 250         19
# 2              1495     1223                 251         20
# 3              1382     1113                 249         20
# 4              1446     1174                 250         21
# 5              1496     1223                 250         22
# 6              1385     1113                 249         22
# 7              1448     1174                 250         23
# 8              1498     1223                 249         24
# 9              1380     1113                 249         17
# 10             1443     1174                 250         18
# 11             1494     1223                 251         19
# 12             1381     1113                 249         18
# 13             1444     1174                 250         20
# 14             1495     1223                 251         21
# 15             1383     1113                 249         20
# 16             1447     1174                 250         22
# 17             1497     1223                 250         23
# 18             1379     1113                 249         16
# 19             1441     1174                 250         17
# 20             1492     1223                 251         18
# 21             1380     1113                 249         17
# 22             1443     1174                 250         19
# 23             1494     1223                 251         20
# 24             1382     1113                 249         19
# 25             1445     1174                 250         21
# 26             1495     1223                 250         22

# %%
area_select('LIGHTCO')
# Out:
#                                Scenario          Area  Number  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS  LIGHTCO            2
# 1     Solar = 0 MW, Hydro = 400 MW, RLS  LIGHTCO            2
# 2     Solar = 0 MW, Hydro = 400 MW, HLS  LIGHTCO            2
# 3     Solar = 0 MW, Hydro = 500 MW, LLS  LIGHTCO            2
# 4     Solar = 0 MW, Hydro = 500 MW, RLS  LIGHTCO            2
# 5     Solar = 0 MW, Hydro = 500 MW, HLS  LIGHTCO            2
# 6     Solar = 0 MW, Hydro = 600 MW, LLS  LIGHTCO            2
# 7     Solar = 0 MW, Hydro = 600 MW, RLS  LIGHTCO            2
# 8     Solar = 0 MW, Hydro = 600 MW, HLS  LIGHTCO            2
# 9    Solar = 50 MW, Hydro = 400 MW, LLS  LIGHTCO            2
# 10   Solar = 50 MW, Hydro = 400 MW, RLS  LIGHTCO            2
# 11   Solar = 50 MW, Hydro = 400 MW, HLS  LIGHTCO            2
# 12   Solar = 50 MW, Hydro = 500 MW, LLS  LIGHTCO            2
# 13   Solar = 50 MW, Hydro = 500 MW, RLS  LIGHTCO            2
# 14   Solar = 50 MW, Hydro = 500 MW, HLS  LIGHTCO            2
# 15   Solar = 50 MW, Hydro = 600 MW, LLS  LIGHTCO            2
# 16   Solar = 50 MW, Hydro = 600 MW, RLS  LIGHTCO            2
# 17   Solar = 50 MW, Hydro = 600 MW, HLS  LIGHTCO            2
# 18  Solar = 100 MW, Hydro = 400 MW, LLS  LIGHTCO            2
# 19  Solar = 100 MW, Hydro = 400 MW, RLS  LIGHTCO            2
# 20  Solar = 100 MW, Hydro = 400 MW, HLS  LIGHTCO            2
# 21  Solar = 100 MW, Hydro = 500 MW, LLS  LIGHTCO            2
# 22  Solar = 100 MW, Hydro = 500 MW, RLS  LIGHTCO            2
# 23  Solar = 100 MW, Hydro = 500 MW, HLS  LIGHTCO            2
# 24  Solar = 100 MW, Hydro = 600 MW, LLS  LIGHTCO            2
# 25  Solar = 100 MW, Hydro = 600 MW, RLS  LIGHTCO            2
# 26  Solar = 100 MW, Hydro = 600 MW, HLS  LIGHTCO            2
#
#     From Generation  To Load  To(+)/From(-) Ties  To Losses
# 0              1321     1391                 -99         29
# 1              1399     1468                -100         31
# 2              1461     1529                -100         33
# 3              1327     1391                -100         35
# 4              1405     1468                 -99         37
# 5              1468     1529                 -99         39
# 6              1334     1391                -100         43
# 7              1413     1468                 -99         45
# 8              1478     1529                 -98         48
# 9              1319     1391                 -99         28
# 10             1398     1468                -100         29
# 11             1460     1529                -100         31
# 12             1325     1391                -100         34
# 13             1404     1468                 -99         36
# 14             1466     1529                -101         38
# 15             1333     1391                -100         41
# 16             1412     1468                 -99         43
# 17             1476     1529                 -98         46
# 18             1318     1391                 -99         26
# 19             1396     1468                -100         28
# 20             1458     1529                -100         30
# 21             1324     1391                -100         32
# 22             1403     1468                 -99         34
# 23             1464     1529                -100         36
# 24             1331     1391                -100         40
# 25             1410     1468                 -99         42
# 26             1474     1529                 -99         44

# %%
area_select('WORLD')
# Out:
#                                Scenario          Area  Number  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS  WORLD              5
# 1     Solar = 0 MW, Hydro = 400 MW, RLS  WORLD              5
# 2     Solar = 0 MW, Hydro = 400 MW, HLS  WORLD              5
# 3     Solar = 0 MW, Hydro = 500 MW, LLS  WORLD              5
# 4     Solar = 0 MW, Hydro = 500 MW, RLS  WORLD              5
# 5     Solar = 0 MW, Hydro = 500 MW, HLS  WORLD              5
# 6     Solar = 0 MW, Hydro = 600 MW, LLS  WORLD              5
# 7     Solar = 0 MW, Hydro = 600 MW, RLS  WORLD              5
# 8     Solar = 0 MW, Hydro = 600 MW, HLS  WORLD              5
# 9    Solar = 50 MW, Hydro = 400 MW, LLS  WORLD              5
# 10   Solar = 50 MW, Hydro = 400 MW, RLS  WORLD              5
# 11   Solar = 50 MW, Hydro = 400 MW, HLS  WORLD              5
# 12   Solar = 50 MW, Hydro = 500 MW, LLS  WORLD              5
# 13   Solar = 50 MW, Hydro = 500 MW, RLS  WORLD              5
# 14   Solar = 50 MW, Hydro = 500 MW, HLS  WORLD              5
# 15   Solar = 50 MW, Hydro = 600 MW, LLS  WORLD              5
# 16   Solar = 50 MW, Hydro = 600 MW, RLS  WORLD              5
# 17   Solar = 50 MW, Hydro = 600 MW, HLS  WORLD              5
# 18  Solar = 100 MW, Hydro = 400 MW, LLS  WORLD              5
# 19  Solar = 100 MW, Hydro = 400 MW, RLS  WORLD              5
# 20  Solar = 100 MW, Hydro = 400 MW, HLS  WORLD              5
# 21  Solar = 100 MW, Hydro = 500 MW, LLS  WORLD              5
# 22  Solar = 100 MW, Hydro = 500 MW, RLS  WORLD              5
# 23  Solar = 100 MW, Hydro = 500 MW, HLS  WORLD              5
# 24  Solar = 100 MW, Hydro = 600 MW, LLS  WORLD              5
# 25  Solar = 100 MW, Hydro = 600 MW, RLS  WORLD              5
# 26  Solar = 100 MW, Hydro = 600 MW, HLS  WORLD              5
#
#     From Generation  To Load  To(+)/From(-) Ties  To Losses
# 0               318      463                -149          3
# 1               343      489                -150          4
# 2               364      509                -150          4
# 3               318      463                -149          4
# 4               343      489                -150          4
# 5               364      509                -150          5
# 6               319      463                -149          4
# 7               343      489                -150          5
# 8               364      509                -151          5
# 9               317      463                -149          3
# 10              343      489                -150          4
# 11              364      509                -150          4
# 12              318      463                -149          4
# 13              343      489                -150          4
# 14              364      509                -150          4
# 15              319      463                -149          4
# 16              343      489                -150          4
# 17              364      509                -151          5
# 18              317      463                -149          3
# 19              343      489                -150          4
# 20              363      509                -150          4
# 21              318      463                -149          3
# 22              343      489                -150          4
# 23              364      509                -150          4
# 24              319      463                -149          4
# 25              343      489                -150          4
# 26              363      509                -151          5

# %% [markdown]
# ##### Total generation and Load

# %%
list_scenario = []
list_gen = []
list_load = []
list_gens = [0,50,100]
list_lsc = ['LLS','RLS','HLS']
list_gen_hydro = [400,500,600] #dry, average, wet hydological scenarios
for gen in list_gens:
    for gen_hy in list_gen_hydro:
        for lsc in list_lsc:
            file_csv_out = 'savnw_sol_' + str(gen) +'_hy_' +str(gen_hy) +'_' + str(lsc)+'_tot.csv'
            data_tot = pd.read_csv(file_csv_out)
            data_gen_load = pd.DataFrame()
            scenario = 'Solar = ' + str(gen) + ' MW, ' + 'Hydro = ' + str(gen_hy) + ' MW, '+ lsc.upper()
            list_scenario.append(scenario)
            generation = data_tot['From Generation'].sum()
            list_gen.append(generation)
            load = data_tot['To Load'].sum()
            list_load.append(load)
gen_load_dict = {'Scenario':list_scenario, 
                 'Generation':list_gen,
                 'Load':list_load}
data_gen_load = pd.DataFrame(data=gen_load_dict)
data_gen_load
# Out:
#                                Scenario  Generation  Load
# 0     Solar = 0 MW, Hydro = 400 MW, LLS        3020  2967
# 1     Solar = 0 MW, Hydro = 400 MW, RLS        3186  3131
# 2     Solar = 0 MW, Hydro = 400 MW, HLS        3320  3261
# 3     Solar = 0 MW, Hydro = 500 MW, LLS        3027  2967
# 4     Solar = 0 MW, Hydro = 500 MW, RLS        3194  3131
# 5     Solar = 0 MW, Hydro = 500 MW, HLS        3328  3261
# 6     Solar = 0 MW, Hydro = 600 MW, LLS        3038  2967
# 7     Solar = 0 MW, Hydro = 600 MW, RLS        3204  3131
# 8     Solar = 0 MW, Hydro = 600 MW, HLS        3340  3261
# 9    Solar = 50 MW, Hydro = 400 MW, LLS        3016  2967
# 10   Solar = 50 MW, Hydro = 400 MW, RLS        3184  3131
# 11   Solar = 50 MW, Hydro = 400 MW, HLS        3318  3261
# 12   Solar = 50 MW, Hydro = 500 MW, LLS        3024  2967
# 13   Solar = 50 MW, Hydro = 500 MW, RLS        3191  3131
# 14   Solar = 50 MW, Hydro = 500 MW, HLS        3325  3261
# 15   Solar = 50 MW, Hydro = 600 MW, LLS        3035  2967
# 16   Solar = 50 MW, Hydro = 600 MW, RLS        3202  3131
# 17   Solar = 50 MW, Hydro = 600 MW, HLS        3337  3261
# 18  Solar = 100 MW, Hydro = 400 MW, LLS        3014  2967
# 19  Solar = 100 MW, Hydro = 400 MW, RLS        3180  3131
# 20  Solar = 100 MW, Hydro = 400 MW, HLS        3313  3261
# 21  Solar = 100 MW, Hydro = 500 MW, LLS        3022  2967
# 22  Solar = 100 MW, Hydro = 500 MW, RLS        3189  3131
# 23  Solar = 100 MW, Hydro = 500 MW, HLS        3322  3261
# 24  Solar = 100 MW, Hydro = 600 MW, LLS        3032  2967
# 25  Solar = 100 MW, Hydro = 600 MW, RLS        3198  3131
# 26  Solar = 100 MW, Hydro = 600 MW, HLS        3332  3261

# %% [markdown]
# ##### Breakdown of generation of each generators

# %% [markdown]
# The generators in the hypothetical SAVNW system are 'NUC-A', 'NUC-B', 'SOLAR_PV', 'URBGEN', 'HYDRO_G', 'MINE_G', 'CATDOG_G'. The generators NUC-A, URBGEN and MINE_G are the swing buses of areas 1, 2, 5 respectively. The contribution of each of the generators to considered load scenarios are obtained.

# %%
def gen_contribution(name):
    '''
    Function to separate contribution of each generators to meet the demand in 
    various solar outputs and load scenarios
    '''
    list_gen = []
    list_gens = [0,50,100]
    list_lsc = ['LLS','RLS','HLS']
    list_gen_hydro = [400,500,600] #dry, average, wet hydological scenarios
    for gen in list_gens:
        for gen_hy in list_gen_hydro:
            for lsc in list_lsc:
                file_csv_out = 'savnw_sol_' + str(gen) +'_hy_' +str(gen_hy) +'_' + str(lsc)+'_gen.csv'
                data_gen = pd.read_csv(file_csv_out, header=1, skiprows=0)
                data_gen['Scenario'] = 'Solar = ' + str(gen) + ' MW, ' + 'Hydro = ' + str(gen_hy) + ' MW, '+ lsc.upper()
                data_new = data_gen[(data_gen['Name'].str.strip()) == name]
                list_gen.append(data_new)
            
    df_area = pd.concat(list_gen)
    df = df_area[['Scenario','Number', 'Name', 'Area', 'Pgen', 'Pmax', 'Reserve']].reset_index(drop=True)
    return df

# %%
gen_contribution('NUC-A')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS     101        NUC-A            1
# 1     Solar = 0 MW, Hydro = 400 MW, RLS     101        NUC-A            1
# 2     Solar = 0 MW, Hydro = 400 MW, HLS     101        NUC-A            1
# 3     Solar = 0 MW, Hydro = 500 MW, LLS     101        NUC-A            1
# 4     Solar = 0 MW, Hydro = 500 MW, RLS     101        NUC-A            1
# 5     Solar = 0 MW, Hydro = 500 MW, HLS     101        NUC-A            1
# 6     Solar = 0 MW, Hydro = 600 MW, LLS     101        NUC-A            1
# 7     Solar = 0 MW, Hydro = 600 MW, RLS     101        NUC-A            1
# 8     Solar = 0 MW, Hydro = 600 MW, HLS     101        NUC-A            1
# 9    Solar = 50 MW, Hydro = 400 MW, LLS     101        NUC-A            1
# 10   Solar = 50 MW, Hydro = 400 MW, RLS     101        NUC-A            1
# 11   Solar = 50 MW, Hydro = 400 MW, HLS     101        NUC-A            1
# 12   Solar = 50 MW, Hydro = 500 MW, LLS     101        NUC-A            1
# 13   Solar = 50 MW, Hydro = 500 MW, RLS     101        NUC-A            1
# 14   Solar = 50 MW, Hydro = 500 MW, HLS     101        NUC-A            1
# 15   Solar = 50 MW, Hydro = 600 MW, LLS     101        NUC-A            1
# 16   Solar = 50 MW, Hydro = 600 MW, RLS     101        NUC-A            1
# 17   Solar = 50 MW, Hydro = 600 MW, HLS     101        NUC-A            1
# 18  Solar = 100 MW, Hydro = 400 MW, LLS     101        NUC-A            1
# 19  Solar = 100 MW, Hydro = 400 MW, RLS     101        NUC-A            1
# 20  Solar = 100 MW, Hydro = 400 MW, HLS     101        NUC-A            1
# 21  Solar = 100 MW, Hydro = 500 MW, LLS     101        NUC-A            1
# 22  Solar = 100 MW, Hydro = 500 MW, RLS     101        NUC-A            1
# 23  Solar = 100 MW, Hydro = 500 MW, HLS     101        NUC-A            1
# 24  Solar = 100 MW, Hydro = 600 MW, LLS     101        NUC-A            1
# 25  Solar = 100 MW, Hydro = 600 MW, RLS     101        NUC-A            1
# 26  Solar = 100 MW, Hydro = 600 MW, HLS     101        NUC-A            1
#
#       Pgen   Pmax  Reserve
# 0   681.11  810.0   128.89
# 1   744.13  810.0    65.87
# 2   795.13  810.0    14.87
# 3   682.99  810.0   127.01
# 4   746.16  810.0    63.84
# 5   796.24  810.0    13.76
# 6   685.03  810.0   124.97
# 7   748.35  810.0    61.65
# 8   798.35  810.0    11.65
# 9   630.08  810.0   179.92
# 10  693.02  810.0   116.98
# 11  744.02  810.0    65.98
# 12  631.90  810.0   178.10
# 13  694.99  810.0   115.01
# 14  745.94  810.0    64.06
# 15  633.86  810.0   176.14
# 16  697.11  810.0   112.89
# 17  747.11  810.0    62.89
# 18  579.10  810.0   230.90
# 19  641.96  810.0   168.04
# 20  692.96  810.0   117.04
# 21  580.86  810.0   229.14
# 22  643.87  810.0   166.13
# 23  694.82  810.0   115.18
# 24  582.76  810.0   227.24
# 25  645.92  810.0   164.08
# 26  695.95  810.0   114.05

# %%
gen_contribution('NUC-B')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS     102        NUC-B            1
# 1     Solar = 0 MW, Hydro = 400 MW, RLS     102        NUC-B            1
# 2     Solar = 0 MW, Hydro = 400 MW, HLS     102        NUC-B            1
# 3     Solar = 0 MW, Hydro = 500 MW, LLS     102        NUC-B            1
# 4     Solar = 0 MW, Hydro = 500 MW, RLS     102        NUC-B            1
# 5     Solar = 0 MW, Hydro = 500 MW, HLS     102        NUC-B            1
# 6     Solar = 0 MW, Hydro = 600 MW, LLS     102        NUC-B            1
# 7     Solar = 0 MW, Hydro = 600 MW, RLS     102        NUC-B            1
# 8     Solar = 0 MW, Hydro = 600 MW, HLS     102        NUC-B            1
# 9    Solar = 50 MW, Hydro = 400 MW, LLS     102        NUC-B            1
# 10   Solar = 50 MW, Hydro = 400 MW, RLS     102        NUC-B            1
# 11   Solar = 50 MW, Hydro = 400 MW, HLS     102        NUC-B            1
# 12   Solar = 50 MW, Hydro = 500 MW, LLS     102        NUC-B            1
# 13   Solar = 50 MW, Hydro = 500 MW, RLS     102        NUC-B            1
# 14   Solar = 50 MW, Hydro = 500 MW, HLS     102        NUC-B            1
# 15   Solar = 50 MW, Hydro = 600 MW, LLS     102        NUC-B            1
# 16   Solar = 50 MW, Hydro = 600 MW, RLS     102        NUC-B            1
# 17   Solar = 50 MW, Hydro = 600 MW, HLS     102        NUC-B            1
# 18  Solar = 100 MW, Hydro = 400 MW, LLS     102        NUC-B            1
# 19  Solar = 100 MW, Hydro = 400 MW, RLS     102        NUC-B            1
# 20  Solar = 100 MW, Hydro = 400 MW, HLS     102        NUC-B            1
# 21  Solar = 100 MW, Hydro = 500 MW, LLS     102        NUC-B            1
# 22  Solar = 100 MW, Hydro = 500 MW, RLS     102        NUC-B            1
# 23  Solar = 100 MW, Hydro = 500 MW, HLS     102        NUC-B            1
# 24  Solar = 100 MW, Hydro = 600 MW, LLS     102        NUC-B            1
# 25  Solar = 100 MW, Hydro = 600 MW, RLS     102        NUC-B            1
# 26  Solar = 100 MW, Hydro = 600 MW, HLS     102        NUC-B            1
#
#      Pgen   Pmax  Reserve
# 0   700.0  810.0    110.0
# 1   700.0  810.0    110.0
# 2   700.0  810.0    110.0
# 3   700.0  810.0    110.0
# 4   700.0  810.0    110.0
# 5   700.0  810.0    110.0
# 6   700.0  810.0    110.0
# 7   700.0  810.0    110.0
# 8   700.0  810.0    110.0
# 9   700.0  810.0    110.0
# 10  700.0  810.0    110.0
# 11  700.0  810.0    110.0
# 12  700.0  810.0    110.0
# 13  700.0  810.0    110.0
# 14  700.0  810.0    110.0
# 15  700.0  810.0    110.0
# 16  700.0  810.0    110.0
# 17  700.0  810.0    110.0
# 18  700.0  810.0    110.0
# 19  700.0  810.0    110.0
# 20  700.0  810.0    110.0
# 21  700.0  810.0    110.0
# 22  700.0  810.0    110.0
# 23  700.0  810.0    110.0
# 24  700.0  810.0    110.0
# 25  700.0  810.0    110.0
# 26  700.0  810.0    110.0

# %% [markdown]
# The reserve capacity obtained with solar power plant is not dependable capacity, and hence wont contribute to firm capacity of the system.

# %%
gen_contribution('SOLAR_PV')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS     103        SOLAR_PV         1
# 1     Solar = 0 MW, Hydro = 400 MW, RLS     103        SOLAR_PV         1
# 2     Solar = 0 MW, Hydro = 400 MW, HLS     103        SOLAR_PV         1
# 3     Solar = 0 MW, Hydro = 500 MW, LLS     103        SOLAR_PV         1
# 4     Solar = 0 MW, Hydro = 500 MW, RLS     103        SOLAR_PV         1
# 5     Solar = 0 MW, Hydro = 500 MW, HLS     103        SOLAR_PV         1
# 6     Solar = 0 MW, Hydro = 600 MW, LLS     103        SOLAR_PV         1
# 7     Solar = 0 MW, Hydro = 600 MW, RLS     103        SOLAR_PV         1
# 8     Solar = 0 MW, Hydro = 600 MW, HLS     103        SOLAR_PV         1
# 9    Solar = 50 MW, Hydro = 400 MW, LLS     103        SOLAR_PV         1
# 10   Solar = 50 MW, Hydro = 400 MW, RLS     103        SOLAR_PV         1
# 11   Solar = 50 MW, Hydro = 400 MW, HLS     103        SOLAR_PV         1
# 12   Solar = 50 MW, Hydro = 500 MW, LLS     103        SOLAR_PV         1
# 13   Solar = 50 MW, Hydro = 500 MW, RLS     103        SOLAR_PV         1
# 14   Solar = 50 MW, Hydro = 500 MW, HLS     103        SOLAR_PV         1
# 15   Solar = 50 MW, Hydro = 600 MW, LLS     103        SOLAR_PV         1
# 16   Solar = 50 MW, Hydro = 600 MW, RLS     103        SOLAR_PV         1
# 17   Solar = 50 MW, Hydro = 600 MW, HLS     103        SOLAR_PV         1
# 18  Solar = 100 MW, Hydro = 400 MW, LLS     103        SOLAR_PV         1
# 19  Solar = 100 MW, Hydro = 400 MW, RLS     103        SOLAR_PV         1
# 20  Solar = 100 MW, Hydro = 400 MW, HLS     103        SOLAR_PV         1
# 21  Solar = 100 MW, Hydro = 500 MW, LLS     103        SOLAR_PV         1
# 22  Solar = 100 MW, Hydro = 500 MW, RLS     103        SOLAR_PV         1
# 23  Solar = 100 MW, Hydro = 500 MW, HLS     103        SOLAR_PV         1
# 24  Solar = 100 MW, Hydro = 600 MW, LLS     103        SOLAR_PV         1
# 25  Solar = 100 MW, Hydro = 600 MW, RLS     103        SOLAR_PV         1
# 26  Solar = 100 MW, Hydro = 600 MW, HLS     103        SOLAR_PV         1
#
#      Pgen   Pmax  Reserve
# 0     0.0  117.0    117.0
# 1     0.0  117.0    117.0
# 2     0.0  117.0    117.0
# 3     0.0  117.0    117.0
# 4     0.0  117.0    117.0
# 5     0.0  117.0    117.0
# 6     0.0  117.0    117.0
# 7     0.0  117.0    117.0
# 8     0.0  117.0    117.0
# 9    50.0  117.0     67.0
# 10   50.0  117.0     67.0
# 11   50.0  117.0     67.0
# 12   50.0  117.0     67.0
# 13   50.0  117.0     67.0
# 14   50.0  117.0     67.0
# 15   50.0  117.0     67.0
# 16   50.0  117.0     67.0
# 17   50.0  117.0     67.0
# 18  100.0  117.0     17.0
# 19  100.0  117.0     17.0
# 20  100.0  117.0     17.0
# 21  100.0  117.0     17.0
# 22  100.0  117.0     17.0
# 23  100.0  117.0     17.0
# 24  100.0  117.0     17.0
# 25  100.0  117.0     17.0
# 26  100.0  117.0     17.0

# %%
gen_contribution('URBGEN')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS     206        URBGEN           2
# 1     Solar = 0 MW, Hydro = 400 MW, RLS     206        URBGEN           2
# 2     Solar = 0 MW, Hydro = 400 MW, HLS     206        URBGEN           2
# 3     Solar = 0 MW, Hydro = 500 MW, LLS     206        URBGEN           2
# 4     Solar = 0 MW, Hydro = 500 MW, RLS     206        URBGEN           2
# 5     Solar = 0 MW, Hydro = 500 MW, HLS     206        URBGEN           2
# 6     Solar = 0 MW, Hydro = 600 MW, LLS     206        URBGEN           2
# 7     Solar = 0 MW, Hydro = 600 MW, RLS     206        URBGEN           2
# 8     Solar = 0 MW, Hydro = 600 MW, HLS     206        URBGEN           2
# 9    Solar = 50 MW, Hydro = 400 MW, LLS     206        URBGEN           2
# 10   Solar = 50 MW, Hydro = 400 MW, RLS     206        URBGEN           2
# 11   Solar = 50 MW, Hydro = 400 MW, HLS     206        URBGEN           2
# 12   Solar = 50 MW, Hydro = 500 MW, LLS     206        URBGEN           2
# 13   Solar = 50 MW, Hydro = 500 MW, RLS     206        URBGEN           2
# 14   Solar = 50 MW, Hydro = 500 MW, HLS     206        URBGEN           2
# 15   Solar = 50 MW, Hydro = 600 MW, LLS     206        URBGEN           2
# 16   Solar = 50 MW, Hydro = 600 MW, RLS     206        URBGEN           2
# 17   Solar = 50 MW, Hydro = 600 MW, HLS     206        URBGEN           2
# 18  Solar = 100 MW, Hydro = 400 MW, LLS     206        URBGEN           2
# 19  Solar = 100 MW, Hydro = 400 MW, RLS     206        URBGEN           2
# 20  Solar = 100 MW, Hydro = 400 MW, HLS     206        URBGEN           2
# 21  Solar = 100 MW, Hydro = 500 MW, LLS     206        URBGEN           2
# 22  Solar = 100 MW, Hydro = 500 MW, RLS     206        URBGEN           2
# 23  Solar = 100 MW, Hydro = 500 MW, HLS     206        URBGEN           2
# 24  Solar = 100 MW, Hydro = 600 MW, LLS     206        URBGEN           2
# 25  Solar = 100 MW, Hydro = 600 MW, RLS     206        URBGEN           2
# 26  Solar = 100 MW, Hydro = 600 MW, HLS     206        URBGEN           2
#
#       Pgen   Pmax  Reserve
# 0   521.13  900.0   378.87
# 1   599.41  900.0   300.59
# 2   661.37  900.0   238.63
# 3   327.19  900.0   572.81
# 4   405.98  900.0   494.02
# 5   469.00  900.0   431.00
# 6   134.59  900.0   765.41
# 7   213.92  900.0   686.08
# 8   278.70  900.0   621.30
# 9   519.84  900.0   380.16
# 10  598.06  900.0   301.94
# 11  660.00  900.0   240.00
# 12  325.79  900.0   574.21
# 13  404.52  900.0   495.48
# 14  466.33  900.0   433.67
# 15  133.06  900.0   766.94
# 16  212.33  900.0   687.67
# 17  276.67  900.0   623.33
# 18  518.61  900.0   381.39
# 19  596.78  900.0   303.22
# 20  658.70  900.0   241.30
# 21  324.45  900.0   575.55
# 22  403.12  900.0   496.88
# 23  464.91  900.0   435.09
# 24  131.60  900.0   768.40
# 25  210.81  900.0   689.19
# 26  274.80  900.0   625.20

# %%
gen_contribution('HYDRO_G')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS     211        HYDRO_G          2
# 1     Solar = 0 MW, Hydro = 400 MW, RLS     211        HYDRO_G          2
# 2     Solar = 0 MW, Hydro = 400 MW, HLS     211        HYDRO_G          2
# 3     Solar = 0 MW, Hydro = 500 MW, LLS     211        HYDRO_G          2
# 4     Solar = 0 MW, Hydro = 500 MW, RLS     211        HYDRO_G          2
# 5     Solar = 0 MW, Hydro = 500 MW, HLS     211        HYDRO_G          2
# 6     Solar = 0 MW, Hydro = 600 MW, LLS     211        HYDRO_G          2
# 7     Solar = 0 MW, Hydro = 600 MW, RLS     211        HYDRO_G          2
# 8     Solar = 0 MW, Hydro = 600 MW, HLS     211        HYDRO_G          2
# 9    Solar = 50 MW, Hydro = 400 MW, LLS     211        HYDRO_G          2
# 10   Solar = 50 MW, Hydro = 400 MW, RLS     211        HYDRO_G          2
# 11   Solar = 50 MW, Hydro = 400 MW, HLS     211        HYDRO_G          2
# 12   Solar = 50 MW, Hydro = 500 MW, LLS     211        HYDRO_G          2
# 13   Solar = 50 MW, Hydro = 500 MW, RLS     211        HYDRO_G          2
# 14   Solar = 50 MW, Hydro = 500 MW, HLS     211        HYDRO_G          2
# 15   Solar = 50 MW, Hydro = 600 MW, LLS     211        HYDRO_G          2
# 16   Solar = 50 MW, Hydro = 600 MW, RLS     211        HYDRO_G          2
# 17   Solar = 50 MW, Hydro = 600 MW, HLS     211        HYDRO_G          2
# 18  Solar = 100 MW, Hydro = 400 MW, LLS     211        HYDRO_G          2
# 19  Solar = 100 MW, Hydro = 400 MW, RLS     211        HYDRO_G          2
# 20  Solar = 100 MW, Hydro = 400 MW, HLS     211        HYDRO_G          2
# 21  Solar = 100 MW, Hydro = 500 MW, LLS     211        HYDRO_G          2
# 22  Solar = 100 MW, Hydro = 500 MW, RLS     211        HYDRO_G          2
# 23  Solar = 100 MW, Hydro = 500 MW, HLS     211        HYDRO_G          2
# 24  Solar = 100 MW, Hydro = 600 MW, LLS     211        HYDRO_G          2
# 25  Solar = 100 MW, Hydro = 600 MW, RLS     211        HYDRO_G          2
# 26  Solar = 100 MW, Hydro = 600 MW, HLS     211        HYDRO_G          2
#
#      Pgen    Pmax  Reserve
# 0   400.0  616.25   216.25
# 1   400.0  616.25   216.25
# 2   400.0  616.25   216.25
# 3   500.0  616.25   116.25
# 4   500.0  616.25   116.25
# 5   500.0  616.25   116.25
# 6   600.0  616.25    16.25
# 7   600.0  616.25    16.25
# 8   600.0  616.25    16.25
# 9   400.0  616.25   216.25
# 10  400.0  616.25   216.25
# 11  400.0  616.25   216.25
# 12  500.0  616.25   116.25
# 13  500.0  616.25   116.25
# 14  500.0  616.25   116.25
# 15  600.0  616.25    16.25
# 16  600.0  616.25    16.25
# 17  600.0  616.25    16.25
# 18  400.0  616.25   216.25
# 19  400.0  616.25   216.25
# 20  400.0  616.25   216.25
# 21  500.0  616.25   116.25
# 22  500.0  616.25   116.25
# 23  500.0  616.25   116.25
# 24  600.0  616.25    16.25
# 25  600.0  616.25    16.25
# 26  600.0  616.25    16.25

# %%
gen_contribution('MINE_G')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS    3011        MINE_G           5
# 1     Solar = 0 MW, Hydro = 400 MW, RLS    3011        MINE_G           5
# 2     Solar = 0 MW, Hydro = 400 MW, HLS    3011        MINE_G           5
# 3     Solar = 0 MW, Hydro = 500 MW, LLS    3011        MINE_G           5
# 4     Solar = 0 MW, Hydro = 500 MW, RLS    3011        MINE_G           5
# 5     Solar = 0 MW, Hydro = 500 MW, HLS    3011        MINE_G           5
# 6     Solar = 0 MW, Hydro = 600 MW, LLS    3011        MINE_G           5
# 7     Solar = 0 MW, Hydro = 600 MW, RLS    3011        MINE_G           5
# 8     Solar = 0 MW, Hydro = 600 MW, HLS    3011        MINE_G           5
# 9    Solar = 50 MW, Hydro = 400 MW, LLS    3011        MINE_G           5
# 10   Solar = 50 MW, Hydro = 400 MW, RLS    3011        MINE_G           5
# 11   Solar = 50 MW, Hydro = 400 MW, HLS    3011        MINE_G           5
# 12   Solar = 50 MW, Hydro = 500 MW, LLS    3011        MINE_G           5
# 13   Solar = 50 MW, Hydro = 500 MW, RLS    3011        MINE_G           5
# 14   Solar = 50 MW, Hydro = 500 MW, HLS    3011        MINE_G           5
# 15   Solar = 50 MW, Hydro = 600 MW, LLS    3011        MINE_G           5
# 16   Solar = 50 MW, Hydro = 600 MW, RLS    3011        MINE_G           5
# 17   Solar = 50 MW, Hydro = 600 MW, HLS    3011        MINE_G           5
# 18  Solar = 100 MW, Hydro = 400 MW, LLS    3011        MINE_G           5
# 19  Solar = 100 MW, Hydro = 400 MW, RLS    3011        MINE_G           5
# 20  Solar = 100 MW, Hydro = 400 MW, HLS    3011        MINE_G           5
# 21  Solar = 100 MW, Hydro = 500 MW, LLS    3011        MINE_G           5
# 22  Solar = 100 MW, Hydro = 500 MW, RLS    3011        MINE_G           5
# 23  Solar = 100 MW, Hydro = 500 MW, HLS    3011        MINE_G           5
# 24  Solar = 100 MW, Hydro = 600 MW, LLS    3011        MINE_G           5
# 25  Solar = 100 MW, Hydro = 600 MW, RLS    3011        MINE_G           5
# 26  Solar = 100 MW, Hydro = 600 MW, HLS    3011        MINE_G           5
#
#       Pgen   Pmax  Reserve
# 0   228.01  900.0   671.99
# 1   253.48  900.0   646.52
# 2   274.25  900.0   625.75
# 3   228.63  900.0   671.37
# 4   253.61  900.0   646.39
# 5   274.61  900.0   625.39
# 6   229.29  900.0   670.71
# 7   253.77  900.0   646.23
# 8   274.36  900.0   625.64
# 9   227.90  900.0   672.10
# 10  253.38  900.0   646.62
# 11  274.06  900.0   625.94
# 12  228.50  900.0   671.50
# 13  253.50  900.0   646.50
# 14  274.52  900.0   625.48
# 15  229.15  900.0   670.85
# 16  253.64  900.0   646.36
# 17  274.13  900.0   625.87
# 18  227.78  900.0   672.22
# 19  253.28  900.0   646.72
# 20  273.89  900.0   626.11
# 21  228.37  900.0   671.63
# 22  253.39  900.0   646.61
# 23  274.32  900.0   625.68
# 24  229.01  900.0   670.99
# 25  253.52  900.0   646.48
# 26  273.93  900.0   626.07

# %%
gen_contribution('CATDOG_G')
# Out:
#                                Scenario  Number                Name  Area  \
# 0     Solar = 0 MW, Hydro = 400 MW, LLS    3018        CATDOG_G         5
# 1     Solar = 0 MW, Hydro = 400 MW, RLS    3018        CATDOG_G         5
# 2     Solar = 0 MW, Hydro = 400 MW, HLS    3018        CATDOG_G         5
# 3     Solar = 0 MW, Hydro = 500 MW, LLS    3018        CATDOG_G         5
# 4     Solar = 0 MW, Hydro = 500 MW, RLS    3018        CATDOG_G         5
# 5     Solar = 0 MW, Hydro = 500 MW, HLS    3018        CATDOG_G         5
# 6     Solar = 0 MW, Hydro = 600 MW, LLS    3018        CATDOG_G         5
# 7     Solar = 0 MW, Hydro = 600 MW, RLS    3018        CATDOG_G         5
# 8     Solar = 0 MW, Hydro = 600 MW, HLS    3018        CATDOG_G         5
# 9    Solar = 50 MW, Hydro = 400 MW, LLS    3018        CATDOG_G         5
# 10   Solar = 50 MW, Hydro = 400 MW, RLS    3018        CATDOG_G         5
# 11   Solar = 50 MW, Hydro = 400 MW, HLS    3018        CATDOG_G         5
# 12   Solar = 50 MW, Hydro = 500 MW, LLS    3018        CATDOG_G         5
# 13   Solar = 50 MW, Hydro = 500 MW, RLS    3018        CATDOG_G         5
# 14   Solar = 50 MW, Hydro = 500 MW, HLS    3018        CATDOG_G         5
# 15   Solar = 50 MW, Hydro = 600 MW, LLS    3018        CATDOG_G         5
# 16   Solar = 50 MW, Hydro = 600 MW, RLS    3018        CATDOG_G         5
# 17   Solar = 50 MW, Hydro = 600 MW, HLS    3018        CATDOG_G         5
# 18  Solar = 100 MW, Hydro = 400 MW, LLS    3018        CATDOG_G         5
# 19  Solar = 100 MW, Hydro = 400 MW, RLS    3018        CATDOG_G         5
# 20  Solar = 100 MW, Hydro = 400 MW, HLS    3018        CATDOG_G         5
# 21  Solar = 100 MW, Hydro = 500 MW, LLS    3018        CATDOG_G         5
# 22  Solar = 100 MW, Hydro = 500 MW, RLS    3018        CATDOG_G         5
# 23  Solar = 100 MW, Hydro = 500 MW, HLS    3018        CATDOG_G         5
# 24  Solar = 100 MW, Hydro = 600 MW, LLS    3018        CATDOG_G         5
# 25  Solar = 100 MW, Hydro = 600 MW, RLS    3018        CATDOG_G         5
# 26  Solar = 100 MW, Hydro = 600 MW, HLS    3018        CATDOG_G         5
#
#     Pgen   Pmax  Reserve
# 0   90.0  117.0     27.0
# 1   90.0  117.0     27.0
# 2   90.0  117.0     27.0
# 3   90.0  117.0     27.0
# 4   90.0  117.0     27.0
# 5   90.0  117.0     27.0
# 6   90.0  117.0     27.0
# 7   90.0  117.0     27.0
# 8   90.0  117.0     27.0
# 9   90.0  117.0     27.0
# 10  90.0  117.0     27.0
# 11  90.0  117.0     27.0
# 12  90.0  117.0     27.0
# 13  90.0  117.0     27.0
# 14  90.0  117.0     27.0
# 15  90.0  117.0     27.0
# 16  90.0  117.0     27.0
# 17  90.0  117.0     27.0
# 18  90.0  117.0     27.0
# 19  90.0  117.0     27.0
# 20  90.0  117.0     27.0
# 21  90.0  117.0     27.0
# 22  90.0  117.0     27.0
# 23  90.0  117.0     27.0
# 24  90.0  117.0     27.0
# 25  90.0  117.0     27.0
# 26  90.0  117.0     27.0

# %% [markdown]
# ##### Firm and Non-firm Installed Capacity

# %%
firm_capacity = gen_contribution('NUC-A').loc[0,'Pmax'] + gen_contribution('NUC-B').loc[0,'Pmax'] +\
          gen_contribution('HYDRO_G').loc[0,'Pmax'] + gen_contribution('HYDRO_G').loc[0,'Pmax'] + gen_contribution('URBGEN').loc[0,'Pmax'] +\
          gen_contribution('MINE_G').loc[0,'Pmax'] + gen_contribution('CATDOG_G').loc[0,'Pmax'] 
firm_capacity
# Out:
# 4769.5

# %%
non_firm_capacity = gen_contribution('SOLAR_PV').loc[0,'Pmax']
non_firm_capacity
# Out:
# 117.0

# %% [markdown]
# ##### Load distribution of the three studied Load scenarios

# %%
def data_lsc(data_excel, year,strg):
    data = pd.read_excel(data_excel)
    pload = 'Pload-Y'+str(year)+strg
    qload = 'Qload-Y'+str(year)+strg
    data_fil = data[['Load','ID',pload,qload]]
    return data_fil

# %% [markdown]
# ##### Low Load Scenario

# %%
data_lls = data_lsc('lls.xlsx',3,'L')
data_lls
# Out:
#    Load  ID  Pload-Y3L  Qload-Y3L
# 0   153   1    185.549     92.820
# 1   154   1    556.738    417.690
# 2   154   2    371.098    324.870
# 3   203   1    278.278    139.230
# 4   205   1   1113.385    649.740
# 5  3005   1     92.729     46.410
# 6  3007   1    185.549     69.615
# 7  3008   1    185.549     69.615

# %%
total_load = data_lls['Pload-Y3L'].sum().round(2)
total_load
# Out:
# 2968.88

# %% [markdown]
# ##### Reference Load Scenario

# %%
data_rls = data_lsc('rls.xlsx',3,'R')
data_rls
# Out:
#    Load  ID  Pload-Y3R  Qload-Y3R
# 0   153   1    195.744      97.92
# 1   154   1    587.328     440.64
# 2   154   2    391.488     342.72
# 3   203   1    293.568     146.88
# 4   205   1   1174.560     685.44
# 5  3005   1     97.824      48.96
# 6  3007   1    195.744      73.44
# 7  3008   1    195.744      73.44

# %%
total_load = data_rls['Pload-Y3R'].sum()
total_load
# Out:
# 3132.0

# %% [markdown]
# ##### High Load Scenario

# %%
data_hls = data_lsc('hls.xlsx',3,'H')
data_hls
# Out:
#    Load  ID  Pload-Y3H  Qload-Y3H
# 0   153   1      203.9      102.0
# 1   154   1      611.8      459.0
# 2   154   2      407.8      357.0
# 3   203   1      305.8      153.0
# 4   205   1     1223.5      714.0
# 5  3005   1      101.9       51.0
# 6  3007   1      203.9       76.5
# 7  3008   1      203.9       76.5

# %%
total_load = data_hls['Pload-Y3H'].sum()
total_load
# Out:
# 3262.5

# %% [markdown]
# ##### Conclusion

# %% [markdown]
# Year 3 Topology 4 Analysis was carried out to determine the following:
# 1. Generation and load totals for each scenario by area
# 2. Contribution of each of the generators to considered load scenarios
# 3. Firm and non-firm capacity contributions of installed resources
# 4. Total load for the three scenarios
